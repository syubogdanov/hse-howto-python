# %% [markdown]
# <div align="center">
#     <a href="https://github.com/syubogdanov/hse-howto-python">
#         <img src="https://cdn-icons-png.flaticon.com/128/1864/1864551.png" height="128px" width="auto">
#     </a>
#     <h3>
#         <b>
#             Продвинутый Python
#         </b>
#     </h3>
#     <i>
#         Абстрактные синтаксические деревья
#     </i>
# </div>
#
# <br>

# %% [markdown]
# **Выполнил(-а):** <Фамилия Имя Отчество>

# %% [markdown]
# **Дополнительные баллы.** За решение *домашнего задания №6* Вам может быть добавлено не более, чем **... бонусных баллов**. Вы можете лишиться не более, чем **... штрафных баллов**.

# %% [markdown]
# **Задание 1. (... баллов)**
#
# Перед Вами стоит задача реализовать консольную утилиту, предназначенную для сравнения текстовых файлов на наличие плагиата. Ваша программа должна предобработать два текста, сравнить их и вывести на стандартный поток вывода (или в файл) процент их схожести. Решение прикрепите в виде ссылки на репозиторий `GitHub`.

# %% [markdown]
# Интерфейс консольной утилиты должен выглядеть следующим образом: `python3 plagiarism.py file1 file2 [OPTIONS]`. При желании допустимо видоизменение. Не заывайте о том, что проверяющий должен будет понять, как пользоваться Вашей программой. Помните о минимальных требованиях к реализации.

# %% [markdown]
# <table align="center">
#     <tr align="center">
#         <td><b>Опция</b></td>
#         <td><b>Сокращение</b></td>
#         <td><b>Описание</b></td>
#     </tr>
#     <tr align="center">
#         <td><code>--help</code></td>
#         <td><code>-h</code></td>
#         <td>Вывести сообщение с подсказкой.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--output file</code></td>
#         <td><code>-o file</code></td>
#         <td>Вместо стандартного потока вывода использовать файл.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--text</code></td>
#         <td><code>-txt</code></td>
#         <td>Сравниваемые файлы содержат обычный текст. По умолчанию.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--python</code></td>
#         <td><code>-py</code></td>
#         <td>Сравниваемые файлы содержат программу на Python.</td>
#     </tr>
# </table>

# %% [markdown]
# Для сравнения текстов на процент плагиата предлагается использовать метрики, основанные на алгоритмах анализа схожести строк. На Ваше усмотрение, мы предлагаем внимательно изучить следующие из них:
#
# - Расстояние Хэмминга;
# - Расстояние Левенштейна;
# - Расстояние Дамерау — Левенштейна;
# - Коэффициент Сёренсена;
# - Сходство Джаро — Винклера;
# - Алгоритм шинглов;
# - Алгоритм Смита — Уотермана.
#
# Для задания достаточно реализовать любую из указанных выше метрик. Отличным решением станет использование сразу нескольких метрик - за это добавим бонусные баллы! Например, Вы сможете выбирать среднее из метрик или максимум из них - решать Вам. А может, Вы и вовсе захотите предоставить выбор метрик пользователю. Вновь напомним лишь о том, что проверяющий должен будет понять: что, откуда и почему.

# %% [markdown]
# Перед использованием метрик Ваши тексты должны пройти предобработку. Правило касается как обычных текстов, так и программ.
#
# Например, в случае программ на Python студенты могут прибегать к следующим ухищрениям:
#
# - Усложнять узлы бинарных операций. К примеру, равносильны `a = 0` и `a = 1 - 1`;
# - Удалять или добавлять аннотацию типов;
# - Удалять или добавлять документацию к функциям, классам и модулям;
# - Добавлять строки, которые не влияют на исполнение. К примеру, код после `return`;
# - Менять стиль переменных. К примеру, переход от `snake_case` к `CamelCase` и наоборот;
# - Менять порядок определения функций и классов;
# - Менять порядок импортов;
# - Добавлять пустые строки или незначащие пробелы.
#
# В частности, минимальные требования к реализации предполагают наличие всех указанных выше методов предобработки.

# %% [markdown]
# Задание творческое, поэтому Вы вольны добавлять и другие методы - не забудьте указать, как они работают и что проверяют. Учитывайте, что обычные тексты тоже требуют предобработки - алгоритм шинглов может навести Вас на некоторые мысли. При желании можете дополнительно учитывать языковые особенности - нет гарантии, что текст на русском языке. Чем больше методов предобработки, которые влияют на метрику, Вы реализуете, тем выше будет выставленная оценка.

# %% [markdown]
# Прочие минимальные требования к реализации:
#
# - Сопровождение всех функций, модулей и классов документацией. Последняя должна исчерпывающе пояснять, как устроен описываемый объект. Используйте стиль, который был предложен на предыдущей лекции.
#
# - Для функций, анализирующих схожесть строк, и для функций, преобразующих узлы программы, необходимо наличие тестов - хотя бы 10 кейсов на каждую из функций. Используйте модули `pytest` и `doctest`. Вынесите отдельным тестом использование модуля `doctest`.

# %%
"""
Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do
eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut
enim ad minim veniam, quis nostrud exercitation ullamco laboris
nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor
in reprehenderit in voluptate velit esse cillum dolore eu fugiat
nulla pariatur. Excepteur sint occaecat cupidatat non proident,
sunt in culpa qui officia deserunt mollit anim id est laborum.
"""
