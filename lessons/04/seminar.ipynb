# %% [markdown]
# <div align="center">
#     <a href="https://github.com/syubogdanov/hse-howto-python">
#         <img src="https://cdn-icons-png.flaticon.com/128/1864/1864652.png" height="128px" width="auto">
#     </a>
#     <h3>
#         <b>
#             Продвинутый Python
#         </b>
#     </h3>
#     <i>
#         Взаимодействие с ОС. Консольные утилиты
#     </i>
# </div>
#
# <br>

# %% [markdown]
# **Задание.** Реализовать консольную утилиту, предназначенную для описания системной конфигурации пользователя. Интерфейс консольной утилиты должен выглядеть следующим образом: `python3 platform.py [OPTIONS]`

# %% [markdown]
# <table>
#     <tr align="center">
#         <td><b>Опция</b></td>
#         <td><b>Сокращенное имя</b></td>
#         <td><b>Описание</b></td>
#     </tr>
#     <tr align="center">
#         <td><code>--system</code></td>
#         <td><code>-</code></td>
#         <td>Получить название операционной системы.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--processor</code></td>
#         <td><code>-</code></td>
#         <td>Получить имя процессора.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--architecture</code></td>
#         <td><code>-</code></td>
#         <td>Получить информацию об архитектуре компьютера.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--version</code></td>
#         <td><code>-</code></td>
#         <td>Поулчить версию операционной системы.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--endian</code></td>
#         <td><code>-</code></td>
#         <td>Получить тип endian-представления чисел.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--float</code></td>
#         <td><code>-</code></td>
#         <td>Получить информацию о представлении float.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--all</code></td>
#         <td><code>-</code></td>
#         <td>Активировть все опции.</td>
#     </tr>
# </table>

# %%
"""
Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do
eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut
enim ad minim veniam, quis nostrud exercitation ullamco laboris
nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor
in reprehenderit in voluptate velit esse cillum dolore eu fugiat
nulla pariatur. Excepteur sint occaecat cupidatat non proident,
sunt in culpa qui officia deserunt mollit anim id est laborum.
"""

# %% [markdown]
# **Задание.** Реализовать консольную утилиту, предназначенную для поиска похожих файлов внутри директории. Достаточно проверять наличие подстроки. Интерфейс консольной утилиты должен выглядеть следующим образом: `python3 search.py pattern [OPTIONS]`.

# %% [markdown]
# <table>
#     <tr align="center">
#         <td><b>Опция</b></td>
#         <td><b>Сокращенное имя</b></td>
#         <td><b>Описание</b></td>
#     </tr>
#     <tr align="center">
#         <td><code>--source path</code></td>
#         <td><code>-s path</code></td>
#         <td>
#             Осуществить поиск в директории <code>path</code>. По
#             умолчанию - текущая директория.
#         </td>
#     </tr>
#     <tr align="center">
#         <td><code>--extension extension</code></td>
#         <td><code>-e extension</code></td>
#         <td>Указать расширение файла.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--no-folders</code></td>
#         <td><code>-</code></td>
#         <td>Не отображать папки в результате.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--no-regular-files</code></td>
#         <td><code>-</code></td>
#         <td>Не отображать регулярные файлы в результате.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--no-symlinks</code></td>
#         <td><code>-</code></td>
#         <td>Не отображать символические ссылки в результате.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--only-folders</code></td>
#         <td><code></code></td>
#         <td>В результате отображать только папки.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--only-regular-files</code></td>
#         <td><code>-</code></td>
#         <td>В результате отображать только регулярные файлы.</td>
#     </tr>
#     <tr align="center">
#         <td><code>--only-symlinks</code></td>
#         <td><code>-</code></td>
#         <td>В результате отображать только символические ссылки.</td>
#     </tr>
# </table>

# %%
"""
Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do
eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut
enim ad minim veniam, quis nostrud exercitation ullamco laboris
nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor
in reprehenderit in voluptate velit esse cillum dolore eu fugiat
nulla pariatur. Excepteur sint occaecat cupidatat non proident,
sunt in culpa qui officia deserunt mollit anim id est laborum.
"""
